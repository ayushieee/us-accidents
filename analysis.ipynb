# %% [markdown]
# ## US ACCIDENTS EXPLORATORY DATA ANALYTICS

# %% [markdown]
# Data Preparation and Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv('US_Accidents_March23.csv')

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# 2        2016-02-08 07:19:27  39.063148  -84.032608       NaN        NaN
# 3        2016-02-08 07:53:34  39.747753  -84.205582       NaN        NaN
# 4        2016-02-08 08:09:07  39.627781  -84.188354       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 0               0.010  ...      False   False  False           False
# 1               0.010  ...      False   False  False           False
# 2               0.010  ...      False   False  False           False
# 3               0.010  ...      False   False  False           False
# 4               0.010  ...      False   False  False           False
# ...               ...  ...        ...     ...    ...             ...
# 7728389         0.543  ...      False   False  False           False
# 7728390         0.338  ...      False   False  False           False
# 7728391         0.561  ...      False   False  False           False
# 7728392         0.772  ...      False   False  False           False
# 7728393         0.537  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0                False        False          Night          Night
# 1                False        False          Night          Night
# 2                 True        False          Night          Night
# 3                False        False          Night            Day
# 4                 True        False            Day            Day
# ...                ...          ...            ...            ...
# 7728389          False        False            Day            Day
# 7728390          False        False            Day            Day
# 7728391          False        False            Day            Day
# 7728392          False        False            Day            Day
# 7728393          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 0                   Night                 Night
# 1                   Night                   Day
# 2                     Day                   Day
# 3                     Day                   Day
# 4                     Day                   Day
# ...                   ...                   ...
# 7728389               Day                   Day
# 7728390               Day                   Day
# 7728391               Day                   Day
# 7728392               Day                   Day
# 7728393               Day                   Day
#
# [7728394 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 13

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# Traffic_Signal           0.000000e+00
# Roundabout               0.000000e+00
# Station                  0.000000e+00
# Stop                     0.000000e+00
# Traffic_Calming          0.000000e+00
# Country                  0.000000e+00
# Turning_Loop             0.000000e+00
# No_Exit                  0.000000e+00
# End_Time                 0.000000e+00
# Start_Time               0.000000e+00
# Severity                 0.000000e+00
# Railway                  0.000000e+00
# Crossing                 0.000000e+00
# Junction                 0.000000e+00
# Give_Way                 0.000000e+00
# Bump                     0.000000e+00
# Amenity                  0.000000e+00
# Start_Lat                0.000000e+00
# Start_Lng                0.000000e+00
# Distance(mi)             0.000000e+00
# Source                   0.000000e+00
# County                   0.000000e+00
# State                    0.000000e+00
# ID                       0.000000e+00
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Exploratory Analysis and Visualization

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
type(cities_by_accident)
# Out:
# pandas.core.series.Series

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.histplot(cities_by_accident, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# City
# Lake Andes                      1
# Catoctin                        1
# Duck Hill                       1
# Westbrookville                  1
# Saint Croix                     1
#                                ..
# Benkelman                       1
# Old Appleton                    1
# Wildrose                        1
# Mc Nabb                         1
# American Fork-Pleasant Grove    1
# Name: count, Length: 1023, dtype: int64

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='mixed', dayfirst=True)

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14396\362819596.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14396\308908771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14396\3630331899.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]
sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14396\4268565558.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
df_2019 = df[df.Start_Time.dt.year == 2019]
df_2019_Bing = df_2019[df_2019.Source == 'MapQuest']
sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14396\4159956570.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# c:\Users\dell\anaconda3\Lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# c:\Users\dell\anaconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\dell\anaconda3\Lib\site-packages\numpy\lib\histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# <Axes: xlabel='Start_Time'>

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Start Latitude and Longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
import folium

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (39.865147, -84.058723)

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (39.865147, -84.058723)

# %%
for x in df[['Start_Lat', 'Start_Lng']].sample(100).iterrows():
    print(x[1])
# Out:
# Start_Lat    30.419163
# Start_Lng   -91.086845
# Name: 2025016, dtype: float64
# Start_Lat    41.637049
# Start_Lng   -93.777131
# Name: 5610687, dtype: float64
# Start_Lat    34.467354
# Start_Lng   -79.898689
# Name: 2536113, dtype: float64
# Start_Lat    29.596239
# Start_Lng   -98.472069
# Name: 3327047, dtype: float64
# Start_Lat    26.661510
# Start_Lng   -81.649307
# Name: 952661, dtype: float64
# Start_Lat     37.381304
# Start_Lng   -121.904296
# Name: 5807979, dtype: float64
# Start_Lat    41.782749
# Start_Lng   -73.755676
# Name: 1274888, dtype: float64
# Start_Lat    30.371710
# Start_Lng   -81.669128
# Name: 5956802, dtype: float64
# Start_Lat     47.158169
# Start_Lng   -122.357162
# Name: 335979, dtype: float64
# Start_Lat     34.408371
# Start_Lng   -119.549454
# Name: 318038, dtype: float64
# Start_Lat     39.606374
# Start_Lng   -104.891742
# Name: 5574175, dtype: float64
# Start_Lat    39.951943
# Start_Lng   -83.012427
# Name: 5193920, dtype: float64
# Start_Lat     39.075989
# Start_Lng   -106.280937
# Name: 575742, dtype: float64
# Start_Lat    25.624072
# Start_Lng   -80.414429
# Name: 5731043, dtype: float64
# Start_Lat    35.332251
# Start_Lng   -82.521628
# Name: 4366858, dtype: float64
# Start_Lat    35.903992
# Start_Lng   -78.769417
# Name: 1906838, dtype: float64
# Start_Lat    39.27080
# Start_Lng   -94.51049
# Name: 3585110, dtype: float64
# Start_Lat    42.77037
# Start_Lng   -78.38873
# Name: 7542540, dtype: float64
# Start_Lat    32.932838
# Start_Lng   -96.803627
# Name: 280764, dtype: float64
# Start_Lat    30.442192
# Start_Lng   -97.830025
# Name: 5213989, dtype: float64
# Start_Lat    41.059826
# Start_Lng   -88.002640
# Name: 175460, dtype: float64
# Start_Lat     33.875553
# Start_Lng   -118.193275
# Name: 1204167, dtype: float64
# Start_Lat    38.099869
# Start_Lng   -85.824509
# Name: 2075263, dtype: float64
# Start_Lat    31.714302
# Start_Lng   -86.730872
# Name: 4121844, dtype: float64
# Start_Lat    33.710872
# Start_Lng   -84.212683
# Name: 3975192, dtype: float64
# Start_Lat    40.051750
# Start_Lng   -83.027863
# Name: 1079982, dtype: float64
# Start_Lat    38.897281
# Start_Lng   -77.023956
# Name: 4737581, dtype: float64
# Start_Lat     34.068869
# Start_Lng   -117.839455
# Name: 7051926, dtype: float64
# Start_Lat    36.779060
# Start_Lng   -77.777863
# Name: 1084486, dtype: float64
# Start_Lat    41.931030
# Start_Lng   -88.120171
# Name: 1101255, dtype: float64
# Start_Lat    27.759761
# Start_Lng   -82.672393
# Name: 4849917, dtype: float64
# Start_Lat    38.955385
# Start_Lng   -77.196121
# Name: 3704239, dtype: float64
# Start_Lat    28.394740
# Start_Lng   -81.694031
# Name: 5153173, dtype: float64
# Start_Lat     33.580494
# Start_Lng   -117.670502
# Name: 2587780, dtype: float64
# Start_Lat    40.003746
# Start_Lng   -83.153893
# Name: 223417, dtype: float64
# Start_Lat    34.707005
# Start_Lng   -86.672043
# Name: 1500985, dtype: float64
# Start_Lat    36.780251
# Start_Lng   -76.432503
# Name: 905348, dtype: float64
# Start_Lat    40.723293
# Start_Lng   -73.346634
# Name: 374581, dtype: float64
# Start_Lat    37.595362
# Start_Lng   -77.510384
# Name: 5193225, dtype: float64
# Start_Lat    34.761360
# Start_Lng   -86.575073
# Name: 715292, dtype: float64
# Start_Lat    44.770536
# Start_Lng   -93.572541
# Name: 5922877, dtype: float64
# Start_Lat    36.154469
# Start_Lng   -86.842331
# Name: 1434303, dtype: float64
# Start_Lat    29.803001
# Start_Lng   -95.493752
# Name: 284717, dtype: float64
# Start_Lat     33.984184
# Start_Lng   -118.440940
# Name: 4344061, dtype: float64
# Start_Lat    27.970240
# Start_Lng   -81.881607
# Name: 1497504, dtype: float64
# Start_Lat    33.889198
# Start_Lng   -79.550697
# Name: 759488, dtype: float64
# Start_Lat    39.759663
# Start_Lng   -89.605255
# Name: 1686816, dtype: float64
# Start_Lat    32.732220
# Start_Lng   -96.822701
# Name: 2396980, dtype: float64
# Start_Lat    30.340906
# Start_Lng   -97.968636
# Name: 3091453, dtype: float64
# Start_Lat    42.642750
# Start_Lng   -71.232193
# Name: 2752908, dtype: float64
# Start_Lat     45.810070
# Start_Lng   -123.961823
# Name: 7688781, dtype: float64
# Start_Lat     33.988577
# Start_Lng   -117.909682
# Name: 6703364, dtype: float64
# Start_Lat     45.65393
# Start_Lng   -122.66313
# Name: 6965881, dtype: float64
# Start_Lat    38.000881
# Start_Lng   -84.520302
# Name: 2497055, dtype: float64
# Start_Lat    30.305441
# Start_Lng   -97.720970
# Name: 387402, dtype: float64
# Start_Lat     33.858414
# Start_Lng   -118.096313
# Name: 2556124, dtype: float64
# Start_Lat     35.441820
# Start_Lng   -119.022071
# Name: 7292751, dtype: float64
# Start_Lat    41.556209
# Start_Lng   -72.104480
# Name: 7458166, dtype: float64
# Start_Lat    41.100744
# Start_Lng   -74.023379
# Name: 5268803, dtype: float64
# Start_Lat    35.616291
# Start_Lng   -97.531693
# Name: 2186979, dtype: float64
# Start_Lat    40.699914
# Start_Lng   -73.986085
# Name: 6884570, dtype: float64
# Start_Lat    40.833102
# Start_Lng   -73.931754
# Name: 6712024, dtype: float64
# Start_Lat    35.723263
# Start_Lng   -78.584641
# Name: 711673, dtype: float64
# Start_Lat     46.930386
# Start_Lng   -112.854298
# Name: 4871338, dtype: float64
# Start_Lat     33.448109
# Start_Lng   -112.037567
# Name: 2169885, dtype: float64
# Start_Lat    39.796440
# Start_Lng   -84.273308
# Name: 3242161, dtype: float64
# Start_Lat    33.542595
# Start_Lng   -84.576912
# Name: 151353, dtype: float64
# Start_Lat     33.916724
# Start_Lng   -117.283460
# Name: 4408303, dtype: float64
# Start_Lat    29.808450
# Start_Lng   -95.441725
# Name: 3882668, dtype: float64
# Start_Lat    41.450710
# Start_Lng   -81.701736
# Name: 1515273, dtype: float64
# Start_Lat     40.414333
# Start_Lng   -111.870087
# Name: 1110465, dtype: float64
# Start_Lat     33.801240
# Start_Lng   -117.148993
# Name: 4019479, dtype: float64
# Start_Lat    28.565504
# Start_Lng   -81.194899
# Name: 4373675, dtype: float64
# Start_Lat    35.849179
# Start_Lng   -78.580328
# Name: 4842518, dtype: float64
# Start_Lat    30.510704
# Start_Lng   -81.634490
# Name: 5178794, dtype: float64
# Start_Lat     33.290568
# Start_Lng   -111.097439
# Name: 3893356, dtype: float64
# Start_Lat    40.769549
# Start_Lng   -80.235645
# Name: 4140494, dtype: float64
# Start_Lat    43.133949
# Start_Lng   -83.763458
# Name: 2985117, dtype: float64
# Start_Lat    26.61767
# Start_Lng   -80.16153
# Name: 1396856, dtype: float64
# Start_Lat    32.778492
# Start_Lng   -96.916878
# Name: 2767493, dtype: float64
# Start_Lat    40.836879
# Start_Lng   -73.873543
# Name: 5209941, dtype: float64
# Start_Lat    42.33660
# Start_Lng   -88.03181
# Name: 3608417, dtype: float64
# Start_Lat    32.782402
# Start_Lng   -96.811653
# Name: 860859, dtype: float64
# Start_Lat     44.667488
# Start_Lng   -123.058380
# Name: 1075292, dtype: float64
# Start_Lat     40.638408
# Start_Lng   -122.946330
# Name: 6353202, dtype: float64
# Start_Lat    40.74182
# Start_Lng   -73.84094
# Name: 3512093, dtype: float64
# Start_Lat     38.378803
# Start_Lng   -123.079956
# Name: 401597, dtype: float64
# Start_Lat    44.768164
# Start_Lng   -94.050698
# Name: 5684527, dtype: float64
# Start_Lat    33.944210
# Start_Lng   -86.420868
# Name: 2528526, dtype: float64
# Start_Lat     37.54887
# Start_Lng   -122.29180
# Name: 3407247, dtype: float64
# Start_Lat    41.257698
# Start_Lng   -95.954567
# Name: 2423487, dtype: float64
# Start_Lat    40.112280
# Start_Lng   -83.036099
# Name: 7423278, dtype: float64
# Start_Lat    42.669525
# Start_Lng   -73.748756
# Name: 2367582, dtype: float64
# Start_Lat     32.776255
# Start_Lng   -117.134128
# Name: 5449956, dtype: float64
# Start_Lat     38.587722
# Start_Lng   -121.446947
# Name: 6872090, dtype: float64
# Start_Lat    36.164249
# Start_Lng   -86.819870
# Name: 2119899, dtype: float64
# Start_Lat     34.003569
# Start_Lng   -117.830784
# Name: 4211965, dtype: float64
# Start_Lat    29.524446
# Start_Lng   -98.479912
# Name: 285526, dtype: float64
# Start_Lat     46.634359
# Start_Lng   -121.403611
# Name: 3708330, dtype: float64
# Start_Lat    28.661943
# Start_Lng   -81.388611
# Name: 2009995, dtype: float64

# %%
for x in df[['Start_Lat', 'Start_Lng']].sample(100).itertuples(index=False):
    print(x)
# Out:
# Pandas(Start_Lat=39.647866, Start_Lng=-77.394351)
# Pandas(Start_Lat=28.494684000000003, Start_Lng=-81.374924)
# Pandas(Start_Lat=32.196301, Start_Lng=-81.198143)
# Pandas(Start_Lat=38.943239450269004, Start_Lng=-77.28599667512279)
# Pandas(Start_Lat=30.288504, Start_Lng=-81.627324)
# Pandas(Start_Lat=37.891613, Start_Lng=-122.061977)
# Pandas(Start_Lat=34.011124, Start_Lng=-118.284884)
# Pandas(Start_Lat=40.57706952075683, Start_Lng=-75.79280018770315)
# Pandas(Start_Lat=38.761826, Start_Lng=-121.164055)
# Pandas(Start_Lat=42.276254, Start_Lng=-88.15456999999998)
# Pandas(Start_Lat=30.520025, Start_Lng=-84.239441)
# Pandas(Start_Lat=36.313447, Start_Lng=-119.788692)
# Pandas(Start_Lat=25.810617, Start_Lng=-80.313379)
# Pandas(Start_Lat=42.599005, Start_Lng=-123.383793)
# Pandas(Start_Lat=47.708061, Start_Lng=-122.344734)
# Pandas(Start_Lat=33.925129, Start_Lng=-118.280952)
# Pandas(Start_Lat=29.833372, Start_Lng=-95.384331)
# Pandas(Start_Lat=33.64915967, Start_Lng=-117.9113996)
# Pandas(Start_Lat=29.034752, Start_Lng=-82.458687)
# Pandas(Start_Lat=25.687189, Start_Lng=-80.356573)
# Pandas(Start_Lat=42.753506, Start_Lng=-73.76798199999998)
# Pandas(Start_Lat=38.122608, Start_Lng=-121.683677)
# Pandas(Start_Lat=40.797947, Start_Lng=-111.949473)
# Pandas(Start_Lat=30.508438, Start_Lng=-91.172638)
# Pandas(Start_Lat=45.02698302, Start_Lng=-93.28584552)
# Pandas(Start_Lat=39.02026, Start_Lng=-94.50114)
# Pandas(Start_Lat=45.915495, Start_Lng=-119.35371200000002)
# Pandas(Start_Lat=41.062023, Start_Lng=-81.50484499999997)
# Pandas(Start_Lat=29.625643, Start_Lng=-95.517792)
# Pandas(Start_Lat=39.035726, Start_Lng=-84.597222)
# Pandas(Start_Lat=30.339779, Start_Lng=-97.699562)
# Pandas(Start_Lat=35.148453, Start_Lng=-80.830887)
# Pandas(Start_Lat=36.081985, Start_Lng=-86.76403)
# Pandas(Start_Lat=25.762691, Start_Lng=-80.26321300000002)
# Pandas(Start_Lat=45.02477, Start_Lng=-93.19077)
# Pandas(Start_Lat=38.652487, Start_Lng=-76.056838)
# Pandas(Start_Lat=34.949417, Start_Lng=-82.894755)
# Pandas(Start_Lat=34.295917, Start_Lng=-94.281899)
# Pandas(Start_Lat=36.881884, Start_Lng=-119.792715)
# Pandas(Start_Lat=25.700645, Start_Lng=-80.446706)
# Pandas(Start_Lat=41.254051, Start_Lng=-76.970863)
# Pandas(Start_Lat=35.806271, Start_Lng=-78.594902)
# Pandas(Start_Lat=35.71693, Start_Lng=-78.655441)
# Pandas(Start_Lat=30.00768542275425, Start_Lng=-90.21654009776012)
# Pandas(Start_Lat=25.884512, Start_Lng=-80.24322)
# Pandas(Start_Lat=39.010241, Start_Lng=-77.081028)
# Pandas(Start_Lat=29.662226, Start_Lng=-95.568855)
# Pandas(Start_Lat=37.275978326619736, Start_Lng=-80.13872981033259)
# Pandas(Start_Lat=34.152390000000004, Start_Lng=-118.157022)
# Pandas(Start_Lat=32.545609000000006, Start_Lng=-84.96122)
# Pandas(Start_Lat=40.78108, Start_Lng=-73.41665)
# Pandas(Start_Lat=35.127407, Start_Lng=-80.942642)
# Pandas(Start_Lat=39.77895, Start_Lng=-86.307953)
# Pandas(Start_Lat=47.46777, Start_Lng=-122.217903)
# Pandas(Start_Lat=46.375572, Start_Lng=-94.155558)
# Pandas(Start_Lat=33.696278, Start_Lng=-117.08447)
# Pandas(Start_Lat=34.065911, Start_Lng=-117.862915)
# Pandas(Start_Lat=34.537682000000004, Start_Lng=-86.912148)
# Pandas(Start_Lat=32.25959, Start_Lng=-111.018669)
# Pandas(Start_Lat=34.378131, Start_Lng=-80.13288100000003)
# Pandas(Start_Lat=37.971598, Start_Lng=-122.319869)
# Pandas(Start_Lat=40.242782, Start_Lng=-75.437937)
# Pandas(Start_Lat=40.6869, Start_Lng=-84.95581999999997)
# Pandas(Start_Lat=30.192408, Start_Lng=-97.925217)
# Pandas(Start_Lat=39.943902, Start_Lng=-82.571182)
# Pandas(Start_Lat=37.678945, Start_Lng=-97.316939)
# Pandas(Start_Lat=45.410439, Start_Lng=-122.524593)
# Pandas(Start_Lat=45.48738, Start_Lng=-122.67863)
# Pandas(Start_Lat=34.014862, Start_Lng=-118.485901)
# Pandas(Start_Lat=42.164037, Start_Lng=-72.509765)
# Pandas(Start_Lat=34.58119, Start_Lng=-118.13364)
# Pandas(Start_Lat=37.719342, Start_Lng=-122.399596)
# Pandas(Start_Lat=38.694321, Start_Lng=-121.368267)
# Pandas(Start_Lat=32.790058, Start_Lng=-96.80024)
# Pandas(Start_Lat=29.992965, Start_Lng=-90.080541)
# Pandas(Start_Lat=41.60588, Start_Lng=-81.45302)
# Pandas(Start_Lat=43.17501, Start_Lng=-85.35347900000002)
# Pandas(Start_Lat=40.850067, Start_Lng=-73.944817)
# Pandas(Start_Lat=43.775349, Start_Lng=-94.994659)
# Pandas(Start_Lat=33.703339, Start_Lng=-84.17023499999998)
# Pandas(Start_Lat=35.06261, Start_Lng=-85.30855)
# Pandas(Start_Lat=37.961319, Start_Lng=-120.236223)
# Pandas(Start_Lat=45.577505, Start_Lng=-122.134683)
# Pandas(Start_Lat=34.771111, Start_Lng=-86.585953)
# Pandas(Start_Lat=35.14711, Start_Lng=-80.744667)
# Pandas(Start_Lat=29.705624, Start_Lng=-95.48513)
# Pandas(Start_Lat=35.28878, Start_Lng=-80.964699)
# Pandas(Start_Lat=40.55111, Start_Lng=-74.54213)
# Pandas(Start_Lat=28.080486059054948, Start_Lng=-82.35296845396827)
# Pandas(Start_Lat=29.436267, Start_Lng=-98.503729)
# Pandas(Start_Lat=40.021422, Start_Lng=-75.23101199999998)
# Pandas(Start_Lat=28.469002000000003, Start_Lng=-81.461525)
# Pandas(Start_Lat=40.151718, Start_Lng=-75.507423)
# Pandas(Start_Lat=32.769123, Start_Lng=-96.83682)
# Pandas(Start_Lat=41.636579, Start_Lng=-112.101984)
# Pandas(Start_Lat=38.584746, Start_Lng=-122.94923)
# Pandas(Start_Lat=45.06658, Start_Lng=-93.24051)
# Pandas(Start_Lat=30.280127, Start_Lng=-81.984377)
# Pandas(Start_Lat=33.860596, Start_Lng=-81.202721)
# Pandas(Start_Lat=38.433705, Start_Lng=-78.855281)

# %%
zip(list(df.Start_Lat), list(df.Start_Lng))

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.001 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d06c117b773575d278942354c2cdfb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d06c117b773575d278942354c2cdfb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d06c117b773575d278942354c2cdfb2 = L.map(
#                 &quot;map_9d06c117b773575d278942354c2cdfb2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2298ffc9652f964df5cd46bff3c07b29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2298ffc9652f964df5cd46bff3c07b29.addTo(map_9d06c117b773575d278942354c2cdfb2);
#
#
#             var heat_map_6f0cd4619f65a6c2ad151cd10b74db4f = L.heatLayer(
#                 [[30.416035, -88.827682], [39.446438, -77.390953], [34.171581, -117.339295], [38.57716, -90.500648], [34.323657, -118.501288], [38.673131, -121.6239], [28.575209, -81.451796], [28.60129, -81.544495], [41.216324, -96.09108], [35.401581, -80.69839499999998], [28.351277000000003, -81.32196400000002], [30.235664, -97.685956], [41.859009, -87.640915], [35.166912, -80.742393], [43.7563, -123.09684], [40.75699, -74.0542], [40.741972, -73.545048], [25.890484, -80.18144000000002], [25.971928, -80.229912], [33.934334, -118.280357], [42.955865, -77.018327], [45.52819132783162, -94.80841755821794], [44.868572, -93.43235], [41.767473, -72.619613], [33.943958, -118.317749], [44.38821, -88.160927], [39.876179, -86.047474], [40.665871, -73.752678], [34.3428, -79.533951], [37.884385, -79.287576], [42.834549, -71.29723800000002], [33.973152, -81.02154499999997], [40.738167, -73.443359], [36.045265, -86.628349], [32.728485, -86.537132], [40.666624, -73.787352], [43.297826, -73.634035], [34.095982, -117.918419], [32.799015999999995, -117.244324], [38.508597, -122.772415], [33.268955, -111.858582], [38.247185, -85.700722], [34.050277, -118.214107], [38.87316, -77.04216], [41.042944, -111.954309], [40.720079, -74.179506], [28.553512, -81.336963], [25.760975, -80.48129300000002], [40.363913, -79.557497], [29.718407, -95.320763], [37.662338, -77.656586], [27.201702, -81.908978], [29.79081, -95.053055], [29.704517, -95.557297], [36.225399, -119.421028], [35.742977, -78.68029], [33.99557, -118.17683], [30.496975, -97.779068], [41.319286, -72.894669], [36.175326, -95.947586], [34.977144, -81.939091], [28.23763, -82.345455], [41.907456, -87.661755], [41.14275, -74.751411], [44.972315, -93.251138], [39.455061, -77.989628], [32.875374, -96.51915], [32.759728, -97.217669], [26.573195, -81.871933], [36.101303, -96.03395], [39.593085050394095, -86.54184937435845], [36.818350553337005, -81.55225396117423], [38.945621, -94.538222], [34.17054, -118.501099], [38.872086, -76.981592], [26.050129, -80.214763], [35.34412000000001, -80.84806999999998], [40.0415504, -76.44728065], [36.663422, -119.754781], [32.766178000000004, -96.85656], [30.32723, -97.727379], [33.364346000000005, -111.601166], [34.177486, -81.323291], [40.102388, -77.043238], [35.20985, -80.75717900000002], [41.51684, -87.31921], [34.206963, -118.217567], [37.182081, -93.279078], [40.33224600000001, -75.97088000000002], [25.888174, -80.164039], [28.210052, -82.73943100000002], [25.733564, -80.300843], [34.42151, -81.812983], [29.852304, -95.32504], [38.173131, -121.664352], [36.06807, -79.766215], [39.960701, -76.611298], [40.08248, -86.30575400000002], [40.844823, -73.924737], [42.923187, -85.58419], [44.891457, -93.58419], [37.915405, -122.32663], [42.502756, -124.410204], [32.367925, -86.132812], [37.701704, -121.886685], [41.116394, -74.113045], [34.020617, -118.158352], [40.85601925830433, -73.97220253909123], [28.448906, -81.40112099999997], [36.93611025792629, -81.16833329162041], [34.004123, -118.064284], [38.314543, -104.663548], [29.655468, -95.570831], [33.41961, -82.05476], [37.551054, -121.918318], [36.97506, -122.011631], [33.863941, -118.285194], [40.72107000000001, -73.9747], [39.740494, -84.204933], [35.27332, -80.83193], [42.397976, -82.98552099999998], [46.16643, -123.837871], [35.421992540190594, -86.87824130016861], [41.632141, -72.873695], [37.900105, -122.31414], [33.877276, -118.135739], [40.18375039, -111.64638162], [36.161396, -86.774856], [32.69746, -96.823242], [33.48764, -112.11706], [41.301411, -72.913338], [33.985664, -118.280396], [25.890177, -80.188547], [29.516901, -98.499245], [38.93021464329276, -122.78044581354722], [33.419615, -84.68255], [37.380689, -120.70338], [40.071018, -75.147987], [41.263023, -96.13884], [37.551682, -77.348602], [39.68153, -75.736786], [40.249008, -75.6614], [34.839088000000004, -82.427856], [42.97628, -85.67806999999998], [29.689404, -95.557404], [33.472938, -112.219

# %% [markdown]
# ## Summary and Conclusion
#
#
# Insights:
# - No data from New York
# - The number of accidents per city decreases exponentially
# - Less than 5% of cities have more than 1000 yearly accidents.
# - Over 1200 cities have reported just one accident (need to investigate)
